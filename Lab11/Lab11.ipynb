# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>ML & DL</b></center>
# <center><b><h1>Lab - 11</b></center>
# <center><b><h1>Kalp Viradia | 23010101299 | 11/02/2026</b></center>
# <pre>

# %% [markdown]
# ## Section 1: PyTorch

# %% [markdown]
# ## Import Torch

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (2.10.0)
# Collecting torchvision
#   Downloading torchvision-0.25.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: filelock in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: numpy in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\college\apps\semesters\semester 4\python\anaconda\lib\site-packages (from jinja2->torch) (2.1.3)
# Downloading torchvision-0.25.0-cp312-cp312-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.3 MB 989.2 kB/s eta 0:00:04
#    ------- -------------------------------- 0.8/4.3 MB 1.1 MB/s eta 0:00:04
#    --------- ------------------------------ 1.0/4.3 MB 1.1 MB/s eta 0:00:04
#    ------------ --------------------------- 1.3/4.3 MB 1.1 MB/s eta 0:00:03
#    ------------ --------------------------- 1.3/4.3 MB 1.1 MB/s eta 0:00:03
#    -------------- ------------------------- 1.6/4.3 MB 1.0 MB/s eta 0:00:03
#    -------------- ------------------------- 1.6/4.3 MB 1.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 1.8/4.3 MB 959.1 kB/s eta 0:00:03
#    ------------------- -------------------- 2.1/4.3 MB 910.7 kB/s eta 0:00:03
#    ------------------- -------------------- 2.1/4.3 MB 910.7 kB/s eta 0:00:03
#    --------------------- ------------------ 2.4/4.3 MB 871.6 kB/s eta 0:00:03
#    --------------------- ------------------ 2.4/4.3 MB 871.6 kB/s eta 0:00:03
#    ------------------------ --------------- 2.6/4.3 MB 843.5 kB/s eta 0:00:02
#    ------------------------ --------------- 2.6/4.3 MB 843.5 kB/s eta 0:00:02
#    -------------------------- ------------- 2.9/4.3 MB 834.9 kB/s eta 0:00:02
#    -------------------------- ------------- 2.9/4.3 MB 834.9 kB/s eta 0:00:02
#    ----------------------------- ---------- 3.1/4.3 MB 831.2 kB/s eta 0:00:02
#    ------------------------------- -------- 3.4/4.3 MB 832.0 kB/s eta 0:00:02
#    ------------------------------- -------- 3.4/4.3 MB 832.0 kB/s eta 0:00:02
#    ---------------------------------- ----- 3.7/4.3 MB 816.8 kB/s eta 0:00:01
#    ---------------------------------- ----- 3.7/4.3 MB 816.8 kB/s eta 0:00:01
#    ------------------------------------ --- 3.9/4.3 MB 796.3 kB/s eta 0:00:01
#    ------------------------------------ --- 3.9/4.3 MB 796.3 kB/s eta 0:00:01
#    -------------------------------------- - 4.2/4.3 MB 786.4 kB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 781.3 kB/s eta 0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.25.0
# WARNING: Ignoring invalid distribution ~ympy (D:\College\Apps\Semesters\Semester 4\Python\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (D:\College\Apps\Semesters\Semester 4\Python\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ympy (D:\College\Apps\Semesters\Semester 4\Python\Anaconda\Lib\site-packages)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ### Task 1: GPU/Device Agnostic Code
# **Goal:** Write code that runs on CPU, CUDA, or MPS (Mac) automatically.

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f'Using device: {device}')

sample_input = torch.randn(1, 10).to(device)
type(sample_input)
# Out:
# Using device: cpu
# torch.Tensor

# %% [markdown]
# ## Section 2: MNIST Project
# Step 1: What is MNIST & Downloading Data
#
# Concept: MNIST is the "Hello World" of Machine Learning. It contains 70,000 images of handwritten digits (0-9).
#
# The Goal: Teach the computer to look at a grid of pixels and say "That is a 7".
#
# The Data: Each image is grayscale and exactly 28×28

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

# transform=ToTensor() converts the image (0-255) to a Torch Tensor (0.0-1.0)

# %%
# Do for Testing

test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %% [markdown]
# ## Visualizing One Image & Understanding Shapes

# %%
len(training_data)
# Out:
# 60000

# %%
len(test_data)
# Out:
# 10000

# %%
img, label = training_data[0]

# %%
img.shape
# Out:
# torch.Size([1, 28, 28])

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## Display one Image in MatplotLib

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img.squeeze(), cmap="gray")
plt.title(f"This is a number {label}")
plt.show()

# %% [markdown]
# # Calculation for the Input Layer

# %% [markdown]
# Concept: We are building a Linear (Feed-Forward) Network,
#
# A Linear Layer consists of neurons in a single vertical line.
#
# Our image is a square grid (28×28).
#
# The Division: We must "cut" the image row by row and stack them into one long line.
#
# The Calculation:
#
# Height×Width=Total Input Features
# 28×28=784
# So, our Input Layer must have 784 neurons.

# %%
img, label = training_data[1]

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## The Architecture (1 Input, 1 Hidden, 1 Output
# The Concept: We will build the simplest standard network.
#
# Input Layer (784): Receives the pixels.
#
# Hidden Layer (128): The "brain" that learns shapes (loops, lines). We pick 128 because it's enough to learn but not too big.
#
# Output Layer (10): The final decision. We have 10 digits (0-9), so we need 10 output scores.

# %%
class SimpleNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()

        self.layer = nn.Sequential(
            nn.Linear(784, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.layer(x)
        return logits

model = SimpleNet()
print(model)
# Out:
# SimpleNet(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (layer): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## Understanding Batch Size (The Stack)
#
# The Concept: Think of the model like a teacher grading exams.
#
# Batch Size = 1: The teacher grades 1 exam, updates the grade book, then picks up the next exam. (Too slow).
#
# Batch Size = 64: The teacher picks up a stack of 64 exams, grades them all at once, and updates the grade book one time for the whole stack. (Much faster).
#
# We use DataLoader to create these "stacks" for us.

# %%
from torch.utils.data import DataLoader

# Create stacks
train_loader = DataLoader(training_data, batch_size=64, shuffle=True)
# do for Test_data
test_loader = DataLoader(test_data, batch_size=64, shuffle=True)

print(len(train_loader),"--",len(test_loader))
# Out:
# 938 -- 157

# %% [markdown]
# ## The Training Loop

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()

# %%
def train():
    model.train()

    for batch_No, (data, target) in enumerate(train_loader):
        output = model(data)
        loss = loss_fn(output, target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch_No % 100 == 0:
            print(f"Batch {batch_No}: Loss = {loss.item():.4f}")

# %%
train()
# Out:
# Batch 0: Loss = 2.3121
# Batch 100: Loss = 0.5461
# Batch 200: Loss = 0.4129
# Batch 300: Loss = 0.4142
# Batch 400: Loss = 0.1704
# Batch 500: Loss = 0.2558
# Batch 600: Loss = 0.2803
# Batch 700: Loss = 0.1815
# Batch 800: Loss = 0.0366
# Batch 900: Loss = 0.2764

# %%
def test():
    model.eval()

    correct = 0
    total = 0

    with torch.no_grad():
        for data, target in test_loader:

            data = data.to(device)
            target = target.to(device)

            output = model(data)

            predicted = torch.argmax(output, dim=1)

            correct += (predicted == target).sum().item()
            total += target.size(0)

    accuracy = 100 * correct / total
    print(f"Test Accuracy: {accuracy:.1f}%")

# %%
test()
# Out:
# Test Accuracy: 94.3%
